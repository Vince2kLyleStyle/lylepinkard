# %% [markdown]
# <a href="https://colab.research.google.com/github/Vince2kLyleStyle/lylepinkard/blob/main/BEST_1_6_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas requests
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import time
import requests
import pandas as pd
from datetime import datetime, timezone

# ===== CONFIG =====
SYMBOLS = {
    "BTC": "BTC-USD",
    "ETH": "ETH-USD",

}

RISK_PER_TRADE = 0.015
STARTING_EQUITY = 10000.0
TAKER_FEE_BPS = 5
SCAN_INTERVAL_S = 60
VERBOSE = True

# Regime TFs
HTF_HOURS = 16  # use 12 if you want 12h instead of 16h

# Discord (replace with your real webhook)
DISCORD_WEBHOOK = "https://discord.com/api/webhooks/1424632435240603719/j5SEFoQZcS-NK3aprki4vq7xcUjKAB2gR4u0vIwqPo4Vlx3QvkPwHEuKn4j0wfnRzPYx"

# ===== STATE =====
equity = STARTING_EQUITY
open_positions: dict = {}
trade_log: list = []

# ===== UTIL =====
def send_discord(message: str) -> None:
    if not DISCORD_WEBHOOK or "REPLACE_ME" in DISCORD_WEBHOOK:
        print("[WARN] No valid DISCORD_WEBHOOK set. Message:", message)
        return
    try:
        r = requests.post(DISCORD_WEBHOOK, json={"content": message}, timeout=10)
        if r.status_code not in (200, 204):
            print(f"[WARN] Discord {r.status_code}: {r.text}")
    except Exception as e:
        print(f"[WARN] Discord send failed: {e}")

def log(msg: str) -> None:
    print(datetime.now(timezone.utc).isoformat(), msg)

# Startup ping (won't send if webhook is placeholder)
send_discord("1/6/16 paper bot (1h signals, 6h + 16h regime) is running ✅")

# ===== DATA FETCH + INDICATORS =====
ALLOWED_MINUTES = [1, 5, 15, 60, 360, 1440]

def snap_minutes(minutes: int) -> int:
    return min(ALLOWED_MINUTES, key=lambda x: abs(x - minutes))

def _fetch_coinbase_window(symbol: str, gran_s: int, start_ts: int, end_ts: int) -> pd.DataFrame:
    params = {
        "start": datetime.fromtimestamp(start_ts, tz=timezone.utc).isoformat(timespec="seconds").replace("+00:00", "Z"),
        "end": datetime.fromtimestamp(end_ts, tz=timezone.utc).isoformat(timespec="seconds").replace("+00:00", "Z"),
        "granularity": gran_s,
    }
    url = f"https://api.exchange.coinbase.com/products/{symbol}/candles"
    try:
        r = requests.get(url, params=params, timeout=20)
        r.raise_for_status()
    except requests.HTTPError:
        try:
            print(f"[{symbol}] Coinbase HTTPError {r.status_code}: {r.text} params={params}")
        except Exception:
            print(f"[{symbol}] Coinbase HTTPError: params={params}")
        return pd.DataFrame()
    except Exception as e:
        print(f"[{symbol}] Coinbase fetch failed: {e}")
        return pd.DataFrame()

    data = r.json() or []
    if not isinstance(data, list) or len(data) == 0:
        return pd.DataFrame()

    df = pd.DataFrame(data, columns=["time", "low", "high", "open", "close", "volume"])
    df["time"] = pd.to_datetime(df["time"], unit="s", utc=True)
    for c in ["open", "high", "low", "close", "volume"]:
        df[c] = pd.to_numeric(df[c], errors="coerce")
    return df.dropna()

def fetch_coinbase_paged(symbol: str, minutes: int, need_bars: int = 1000) -> pd.DataFrame:
    minutes = snap_minutes(int(minutes))
    gran = minutes * 60
    end = int(time.time() // gran * gran)
    out = []
    remaining = max(int(need_bars), 1)
    while remaining > 0:
        chunk_bars = min(300, remaining)
        start = end - chunk_bars * gran
        df = _fetch_coinbase_window(symbol, gran, start, end)
        if df.empty:
            break
        out.append(df)
        remaining -= len(df)
        # step end to before earliest returned candle to avoid overlap
        end = int(df["time"].min().timestamp()) - gran
        # guard to avoid too many tiny fetches if API returns small windows
        if len(df) < 10:
            break
    if not out:
        return pd.DataFrame()
    df_all = pd.concat(out, ignore_index=True)
    df_all = df_all.sort_values("time").reset_index(drop=True)
    df_all = df_all.drop_duplicates(subset=["time"])
    return df_all

def fetch_coinbase(symbol: str, minutes: int, need_bars: int = 500) -> pd.DataFrame:
    minutes = snap_minutes(int(minutes))
    # Always use paged fetching to respect the 300-candle limit
    return fetch_coinbase_paged(symbol, minutes, need_bars=max(need_bars, 1))

def resample_ohlcv_1h(df1h: pd.DataFrame, hours: int) -> pd.DataFrame:
    if df1h.empty:
        return df1h
    d = df1h.copy().set_index("time")
    agg = {"open": "first", "high": "max", "low": "min", "close": "last", "volume": "sum"}
    out = d.resample(f"{hours}h").agg(agg).dropna().reset_index()  # use 'h' to silence FutureWarning
    return out

def ema(s, span):
    return s.ewm(span=span, adjust=False).mean()

def macd(close):
    m = ema(close, 12) - ema(close, 26)
    sg = ema(m, 9)
    return m, sg, m - sg

def mfi_like(df, period=60):
    tp = (df["high"] + df["low"] + df["close"]) / 3.0
    mf = tp * df["volume"]
    up = (tp > tp.shift(1)).astype(float)
    dn = (tp < tp.shift(1)).astype(float)
    pos = mf.mul(up).rolling(period, min_periods=1).mean()
    neg = mf.mul(dn).rolling(period, min_periods=1).mean().replace(0, 1e-12)
    ratio = pos / neg
    return 100.0 - (100.0 / (1.0 + ratio))

def wavetrend(src):
    esa = src.ewm(span=9, adjust=False).mean()
    de = (src - esa).abs().ewm(span=9, adjust=False).mean().replace(0, 1e-12)
    ci = (src - esa) / (0.015 * de)
    wt1 = ci.ewm(span=12, adjust=False).mean()
    wt2 = wt1.rolling(3, min_periods=1).mean()
    return wt1, wt2

def atr(df, n=14):
    prev = df["close"].shift(1)
    tr = pd.concat(
        [
            df["high"] - df["low"],
            (df["high"] - prev).abs(),
            (df["low"] - prev).abs(),
        ],
        axis=1,
    ).max(axis=1)
    return tr.rolling(n, min_periods=1).mean()

def fee_amount(price, qty, bps=TAKER_FEE_BPS):
    return price * qty * (bps / 10000.0)

def _secs_to_next_hour() -> str:
    now = datetime.now(timezone.utc)
    nxt = (now.replace(minute=0, second=0, microsecond=0) + pd.Timedelta(hours=1))
    delta = (nxt - now).total_seconds()
    m, s = divmod(int(delta), 60)
    return f"{m}m {s}s"

# ===== CTR + ENGINE =====
def generate_signal(symbol: str, prod: str):
    # 1h for signals & HTF resample; 6h native for regime
    df1h = fetch_coinbase(prod, 60, need_bars=2000)
    df6h = fetch_coinbase(prod, 360, need_bars=400)

    if df1h.empty or df6h.empty:
        if VERBOSE:
            log(f"[{symbol}] missing data (1h/6h)")
        return None

    # Build HTF from 1h
    dfHTF = resample_ohlcv_1h(df1h, HTF_HOURS)
    if dfHTF.empty or len(dfHTF) < 5:  # need only a few HTF bars
        if VERBOSE:
            log(f"[{symbol}] missing HTF ({HTF_HOURS}h) from 1h resample")
        return None

    # 1h WT + MFI
    src1h = (df1h["high"] + df1h["low"] + df1h["close"]) / 3.0
    wt1, wt2 = wavetrend(src1h)
    mfi1 = mfi_like(df1h, 60)
    crossUp = (wt1 > wt2) & (wt1.shift(1) <= wt2.shift(1))
    crossDn = (wt1 < wt2) & (wt1.shift(1) >= wt2.shift(1))
    mfi1g = (mfi1 > 50)

    # 6h regime (MACD+MFI)
    _, _, h6 = macd(df6h["close"])
    mfi6 = mfi_like(df6h, 60)
    ok6 = bool(h6.iloc[-1] > 0 and mfi6.iloc[-1] > 50)

    # HTF regime (MACD+MFI) from resample
    _, _, hHTF = macd(dfHTF["close"])
    mfiHTF = mfi_like(dfHTF, 60)
    okHTF = bool(hHTF.iloc[-1] > 0 and mfiHTF.iloc[-1] > 50)

    multiBull = ok6 and okHTF
    multiBear = (not ok6) and (not okHTF)

    # 1h ATR TP/SL
    c = float(df1h["close"].iloc[-1])
    A = float(atr(df1h, 14).iloc[-1])
    R = 1.5 * A
    slBuy, tp1Buy, tp2Buy = c - R, c + 1.0 * R, c + 2.0 * R
    slSell, tp1Sell, tp2Sell = c + R, c - 1.0 * R, c - 2.0 * R

    # Raw latest values
    wt1v = float(wt1.iloc[-1])
    wt2v = float(wt2.iloc[-1])
    mfi1v = float(mfi1.iloc[-1])
    mfi6v = float(mfi6.iloc[-1])
    mfiHTFv = float(mfiHTF.iloc[-1])
    h6v = float(h6.iloc[-1])
    hHTFv = float(hHTF.iloc[-1])
    cu = bool(crossUp.iloc[-1])
    cd = bool(crossDn.iloc[-1])

    # Alignment scoring and blockers
    alignLong = int(cu) + int(mfi1v > 50) + int(ok6) + int(okHTF)
    alignShort = int(cd) + int(mfi1v < 50) + int((not ok6)) + int((not okHTF))

    blockedLong = []
    if not cu:
        blockedLong.append("no_fresh_WT_up")
    if not (mfi1v > 50):
        blockedLong.append("MFI1h<=50")
    if not ok6:
        blockedLong.append("6h_regime_false")
    if not okHTF:
        blockedLong.append(f"{HTF_HOURS}h_regime_false")

    blockedShort = []
    if not cd:
        blockedShort.append("no_fresh_WT_dn")
    if not (mfi1v < 50):
        blockedShort.append("MFI1h>=50")
    if ok6:
        blockedShort.append("6h_regime_true")
    if okHTF:
        blockedShort.append(f"{HTF_HOURS}h_regime_true")

    # Cross recency (bars since last cross)
    try:
        last_up_idx = crossUp[::-1].idxmax() if crossUp.any() else None
        last_dn_idx = crossDn[::-1].idxmax() if crossDn.any() else None
        barsSinceUp = (len(crossUp) - 1 - last_up_idx) if last_up_idx is not None else None
        barsSinceDn = (len(crossDn) - 1 - last_dn_idx) if last_dn_idx is not None else None
    except Exception:
        barsSinceUp = None
        barsSinceDn = None

    # Verbose multi-line status
    if VERBOSE:
        log(
            "\n".join(
                [
                    f"[{symbol} STATUS]",
                    f"  price={c:.2f}  next1hClose={_secs_to_next_hour()}  ATR1h={A:.2f}",
                    f"  1h: WT1={wt1v:.2f} WT2={wt2v:.2f} cross={'up' if cu else ('down' if cd else 'none')}  MFI={mfi1v:.1f}",
                    f"      lastCrossBarsAgo: up={barsSinceUp if barsSinceUp is not None else 'n/a'}, dn={barsSinceDn if barsSinceDn is not None else 'n/a'}",
                    f"  6h: MACDh={h6v:.5f} MFI={mfi6v:.1f} OK={ok6}",
                    f"{HTF_HOURS}h: MACDh={hHTFv:.5f} MFI={mfiHTFv:.1f} OK={okHTF}",
                    f"  alignLong={alignLong}/4 blockedLong={blockedLong}",
                    f"  alignShort={alignShort}/4 blockedShort={blockedShort}",
                ]
            )
        )
        # Compact one-liner too
        log(
            f"[{symbol}] c={c:.2f} | L:{alignLong}/4 S:{alignShort}/4 | "
            f"1h:WT_up={cu} WT_dn={cd} MFI={mfi1v:.1f} | 6hOK={ok6} {HTF_HOURS}hOK={okHTF}"
        )

    buy = cu and (mfi1v > 50) and multiBull
    sell = cd and (mfi1v < 50) and multiBear

    if buy:
        log(f"[{symbol}] → BUY setup confirmed (alignLong={alignLong}/4). SL={slBuy:.2f} TP1={tp1Buy:.2f} TP2={tp2Buy:.2f}")
        return {"symbol": symbol, "side": "BUY", "entry": float(c), "sl": float(slBuy), "tp1": float(tp1Buy), "tp2": float(tp2Buy)}
    if sell:
        log(f"[{symbol}] → SELL setup confirmed (alignShort={alignShort}/4). SL={slSell:.2f} TP1={tp1Sell:.2f} TP2={tp2Sell:.2f}")
        return {"symbol": symbol, "side": "SELL", "entry": float(c), "sl": float(slSell), "tp1": float(tp1Sell), "tp2": float(tp2Sell)}

    return None

def open_position(signal: dict):
    global equity, open_positions, trade_log
    sym = signal["symbol"]
    side = signal["side"]
    entry = signal["entry"]
    sl = signal["sl"]
    tp1 = signal["tp1"]
    tp2 = signal["tp2"]
    stop_width = abs(entry - sl)
    if stop_width <= 0:
        log(f"[{sym}] skip: zero stop width")
        return
    risk_usd = equity * RISK_PER_TRADE
    qty = risk_usd / stop_width
    fee = fee_amount(entry, qty)
    pos = {
        "symbol": sym,
        "side": side,
        "entry": entry,
        "qty": qty,
        "sl": sl,
        "tp1": tp1,
        "tp2": tp2,
        "open_time": datetime.now(timezone.utc).isoformat(),
        "status": "open",
        "filled_tp1": False,
    }
    open_positions[sym] = pos
    trade_log.append({"symbol": sym, "action": "OPEN_" + side, "price": entry, "qty": qty, "fee": fee, "time": datetime.now(timezone.utc).isoformat()})
    msg = f"[{sym}] OPEN {side} @ {entry:.2f} qty={qty:.6f} SL={sl:.2f} TP1={tp1:.2f} TP2={tp2:.2f}"
    log(msg)
    send_discord(msg)

def process_tp_sl(symbol: str, last_price: float):
    global equity, open_positions, trade_log
    if symbol not in open_positions:
        return
    p = open_positions[symbol]
    if p["status"] != "open":
        return

    side = p["side"]
    qty = p["qty"]
    entry = p["entry"]
    sl = p["sl"]
    tp1 = p["tp1"]
    tp2 = p["tp2"]

    # SL
    hit_sl = (last_price <= sl) if side == "BUY" else (last_price >= sl)
    if hit_sl:
        fee = fee_amount(last_price, qty)
        pnl = (last_price - entry) * qty if side == "BUY" else (entry - last_price) * qty
        equity += (pnl - fee)
        trade_log.append({"symbol": symbol, "action": "CLOSE_SL", "price": last_price, "qty": qty, "fee": fee, "pnl": pnl, "time": datetime.now(timezone.utc).isoformat()})
        p["status"] = "closed"
        msg = f"[{symbol}] SL HIT @ {last_price:.2f} PnL={pnl:.2f} eq={equity:.2f}"
        log(msg)
        send_discord(msg)
        return

    # TP1 (40% + SL -> BE)
    if not p.get("filled_tp1", False):
        hit_tp1 = (last_price >= tp1) if side == "BUY" else (last_price <= tp1)
        if hit_tp1:
            qty1 = qty * 0.4
            fee = fee_amount(last_price, qty1)
            pnl = (last_price - entry) * qty1 if side == "BUY" else (entry - last_price) * qty1
            equity += (pnl - fee)
            trade_log.append({"symbol": symbol, "action": "TP1", "price": last_price, "qty": qty1, "fee": fee, "pnl": pnl, "time": datetime.now(timezone.utc).isoformat()})
            p["qty"] = qty * 0.6
            p["filled_tp1"] = True
            p["sl"] = entry
            msg = f"[{symbol}] TP1 @ {last_price:.2f} partial PnL={pnl:.2f}; SL->BE; rem qty={p['qty']:.6f}"
            log(msg)
            send_discord(msg)
            return

    # TP2 (close rest)
    hit_tp2 = (last_price >= tp2) if side == "BUY" else (last_price <= tp2)
    if hit_tp2:
        qty2 = p["qty"]
        fee = fee_amount(last_price, qty2)
        pnl = (last_price - entry) * qty2 if side == "BUY" else (entry - last_price) * qty2
        equity += (pnl - fee)
        trade_log.append({"symbol": symbol, "action": "TP2", "price": last_price, "qty": qty2, "fee": fee, "pnl": pnl, "time": datetime.now(timezone.utc).isoformat()})
        p["status"] = "closed"
        msg = f"[{symbol}] TP2 @ {last_price:.2f} PnL={pnl:.2f} eq={equity:.2f}"
        log(msg)
        send_discord(msg)

def latest_close(prod: str):
    df1 = _fetch_coinbase_window(prod, 60, int(time.time()) - 90 * 60, int(time.time()))
    if df1.empty:
        return None
    return float(df1.sort_values("time")["close"].iloc[-1])

def loop_once():
    for sym, prod in SYMBOLS.items():
        try:
            if sym not in open_positions or open_positions[sym]["status"] != "open":
                sig = generate_signal(sym, prod)
                if sig:
                    open_position(sig)

            lp = latest_close(prod)
            if lp is not None:
                process_tp_sl(sym, lp)

        except Exception as e:
            log(f"[{sym}] ERROR: {e}")
            continue

    open_count = sum(1 for v in open_positions.values() if isinstance(v, dict) and v.get("status") == "open")
    log(f"[HEARTBEAT] equity={equity:.2f} open_positions={open_count}")

# ===== MAIN LOOP =====
if __name__ == "__main__":
    try:
        while True:
            loop_once()
            time.sleep(SCAN_INTERVAL_S)
    except KeyboardInterrupt:
        log("Shutting down gracefully (KeyboardInterrupt).")
        pass
# Out:
# Streaming output truncated to the last 5000 lines.
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T17:54:28.799029+00:00 [ETH] c=4480.30 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.0 | 6hOK=False 16hOK=False
# 2025-10-07T17:54:28.929275+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T17:55:29.441191+00:00 [BTC STATUS]
#   price=121221.79  next1hClose=4m 30s  ATR1h=825.67
#   1h: WT1=-71.95 WT2=-64.73 cross=none  MFI=44.3
#       lastCrossBarsAgo: up=8, dn=3
#   6h: MACDh=-410.96689 MFI=63.2 OK=False
# 16h: MACDh=717.60004 MFI=58.4 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T17:55:29.441304+00:00 [BTC] c=121221.79 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.3 | 6hOK=False 16hOK=True
# 2025-10-07T17:55:30.137793+00:00 [ETH STATUS]
#   price=4480.30  next1hClose=4m 29s  ATR1h=53.16
#   1h: WT1=-50.35 WT2=-37.68 cross=none  MFI=55.0
#       lastCrossBarsAgo: up=7, dn=3
#   6h: MACDh=-5.33390 MFI=57.9 OK=False
# 16h: MACDh=45.08621 MFI=48.1 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T17:55:30.137901+00:00 [ETH] c=4480.30 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.0 | 6hOK=False 16hOK=False
# 2025-10-07T17:55:30.194098+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T17:56:30.726504+00:00 [BTC STATUS]
#   price=121221.79  next1hClose=3m 29s  ATR1h=825.67
#   1h: WT1=-71.95 WT2=-64.73 cross=none  MFI=44.3
#       lastCrossBarsAgo: up=8, dn=3
#   6h: MACDh=-410.96689 MFI=63.2 OK=False
# 16h: MACDh=717.60004 MFI=58.4 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T17:56:30.726634+00:00 [BTC] c=121221.79 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.3 | 6hOK=False 16hOK=True
# 2025-10-07T17:56:31.315844+00:00 [ETH STATUS]
#   price=4480.30  next1hClose=3m 28s  ATR1h=53.16
#   1h: WT1=-50.35 WT2=-37.68 cross=none  MFI=55.0
#       lastCrossBarsAgo: up=7, dn=3
#   6h: MACDh=-5.71553 MFI=57.9 OK=False
# 16h: MACDh=45.08621 MFI=48.1 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T17:56:31.315950+00:00 [ETH] c=4480.30 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.0 | 6hOK=False 16hOK=False
# 2025-10-07T17:56:31.434899+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T17:57:31.842615+00:00 [BTC STATUS]
#   price=121221.79  next1hClose=2m 28s  ATR1h=825.67
#   1h: WT1=-71.95 WT2=-64.73 cross=none  MFI=44.3
#       lastCrossBarsAgo: up=8, dn=3
#   6h: MACDh=-410.96689 MFI=63.2 OK=False
# 16h: MACDh=717.60004 MFI=58.4 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T17:57:31.842749+00:00 [BTC] c=121221.79 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.3 | 6hOK=False 16hOK=True
# 2025-10-07T17:57:32.547806+00:00 [ETH STATUS]
#   price=4480.30  next1hClose=2m 27s  ATR1h=53.16
#   1h: WT1=-50.35 WT2=-37.68 cross=none  MFI=55.0
#       lastCrossBarsAgo: up=7, dn=3
#   6h: MACDh=-5.71553 MFI=57.9 OK=False
# 16h: MACDh=45.08621 MFI=48.1 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T17:57:32.547930+00:00 [ETH] c=4480.30 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.0 | 6hOK=False 16hOK=False
# 2025-10-07T17:57:32.678498+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T17:58:33.118654+00:00 [BTC STATUS]
#   price=121221.79  next1hClose=1m 26s  ATR1h=825.67
#   1h: WT1=-71.95 WT2=-64.73 cross=none  MFI=44.3
#       lastCrossBarsAgo: up=8, dn=3
#   6h: MACDh=-410.96689 MFI=63.2 OK=False
# 16h: MACDh=717.60004 MFI=58.4 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T17:58:33.118775+00:00 [BTC] c=121221.79 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.3 | 6hOK=False 16hOK=True
# 2025-10-07T17:58:33.799292+00:00 [ETH STATUS]
#   price=4480.30  next1hClose=1m 26s  ATR1h=53.16
#   1h: WT1=-50.35 WT2=-37.68 cross=none  MFI=55.0
#       lastCrossBarsAgo: up=7, dn=3
#   6h: MACDh=-5.71553 MFI=57.9 OK=False
# 16h: MACDh=45.08621 MFI=48.1 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T17:58:33.799399+00:00 [ETH] c=4480.30 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.0 | 6hOK=False 16hOK=False
# 2025-10-07T17:58:33.921431+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T17:59:35.100117+00:00 [BTC STATUS]
#   price=121238.26  next1hClose=0m 24s  ATR1h=829.76
#   1h: WT1=-72.03 WT2=-64.76 cross=none  MFI=44.2
#       lastCrossBarsAgo: up=8, dn=3
#   6h: MACDh=-409.91581 MFI=63.2 OK=False
# 16h: MACDh=718.65111 MFI=58.4 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T17:59:35.100238+00:00 [BTC] c=121238.26 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.2 | 6hOK=False 16hOK=True
# 2025-10-07T17:59:36.247871+00:00 [ETH STATUS]
#   price=4477.80  next1hClose=0m 23s  ATR1h=53.64
#   1h: WT1=-50.59 WT2=-37.76 cross=none  MFI=54.9
#       lastCrossBarsAgo: up=7, dn=3
#   6h: MACDh=-5.71553 MFI=57.9 OK=False
# 16h: MACDh=44.92667 MFI=48.1 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T17:59:36.247980+00:00 [ETH] c=4477.80 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.9 | 6hOK=False 16hOK=False
# 2025-10-07T17:59:36.375513+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:00:37.675476+00:00 [BTC STATUS]
#   price=121197.88  next1hClose=59m 22s  ATR1h=793.29
#   1h: WT1=-74.27 WT2=-71.10 cross=none  MFI=44.6
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.77867 MFI=64.1 OK=False
# 16h: MACDh=716.07416 MFI=58.4 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:00:37.675613+00:00 [BTC] c=121197.88 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.6 | 6hOK=False 16hOK=True
# 2025-10-07T18:00:39.036429+00:00 [ETH STATUS]
#   price=4477.49  next1hClose=59m 20s  ATR1h=51.07
#   1h: WT1=-55.85 WT2=-49.06 cross=none  MFI=55.3
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.72715 MFI=59.1 OK=False
# 16h: MACDh=44.90688 MFI=48.1 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:00:39.036565+00:00 [ETH] c=4477.49 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.3 | 6hOK=False 16hOK=False
# 2025-10-07T18:00:39.249581+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:01:39.816344+00:00 [BTC STATUS]
#   price=121197.88  next1hClose=58m 20s  ATR1h=793.29
#   1h: WT1=-74.27 WT2=-71.10 cross=none  MFI=44.6
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.77867 MFI=64.1 OK=False
# 16h: MACDh=716.07416 MFI=58.4 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:01:39.816468+00:00 [BTC] c=121197.88 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.6 | 6hOK=False 16hOK=True
# 2025-10-07T18:01:40.524739+00:00 [ETH STATUS]
#   price=4477.49  next1hClose=58m 19s  ATR1h=51.07
#   1h: WT1=-55.85 WT2=-49.06 cross=none  MFI=55.3
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.72715 MFI=59.1 OK=False
# 16h: MACDh=44.90688 MFI=48.1 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:01:40.524848+00:00 [ETH] c=4477.49 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.3 | 6hOK=False 16hOK=False
# 2025-10-07T18:01:40.594043+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:02:41.072662+00:00 [BTC STATUS]
#   price=121197.88  next1hClose=57m 18s  ATR1h=793.29
#   1h: WT1=-74.27 WT2=-71.10 cross=none  MFI=44.6
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.77867 MFI=64.1 OK=False
# 16h: MACDh=716.07416 MFI=58.4 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:02:41.072789+00:00 [BTC] c=121197.88 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.6 | 6hOK=False 16hOK=True
# 2025-10-07T18:02:41.676865+00:00 [ETH STATUS]
#   price=4477.49  next1hClose=57m 18s  ATR1h=51.07
#   1h: WT1=-55.85 WT2=-49.06 cross=none  MFI=55.3
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.72715 MFI=59.1 OK=False
# 16h: MACDh=44.90688 MFI=48.1 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:02:41.676972+00:00 [ETH] c=4477.49 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.3 | 6hOK=False 16hOK=False
# 2025-10-07T18:02:41.831501+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:03:42.358104+00:00 [BTC STATUS]
#   price=121197.88  next1hClose=56m 17s  ATR1h=793.29
#   1h: WT1=-74.27 WT2=-71.10 cross=none  MFI=44.6
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.77867 MFI=64.1 OK=False
# 16h: MACDh=716.07416 MFI=58.4 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:03:42.358231+00:00 [BTC] c=121197.88 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.6 | 6hOK=False 16hOK=True
# 2025-10-07T18:03:42.930978+00:00 [ETH STATUS]
#   price=4477.49  next1hClose=56m 17s  ATR1h=51.07
#   1h: WT1=-55.85 WT2=-49.06 cross=none  MFI=55.3
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.72715 MFI=59.1 OK=False
# 16h: MACDh=44.90688 MFI=48.1 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:03:42.931088+00:00 [ETH] c=4477.49 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.3 | 6hOK=False 16hOK=False
# 2025-10-07T18:03:43.065310+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:04:43.560244+00:00 [BTC STATUS]
#   price=121197.88  next1hClose=55m 16s  ATR1h=793.29
#   1h: WT1=-74.27 WT2=-71.10 cross=none  MFI=44.6
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.77867 MFI=64.1 OK=False
# 16h: MACDh=716.07416 MFI=58.4 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:04:43.560383+00:00 [BTC] c=121197.88 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.6 | 6hOK=False 16hOK=True
# 2025-10-07T18:04:44.241696+00:00 [ETH STATUS]
#   price=4477.49  next1hClose=55m 15s  ATR1h=51.07
#   1h: WT1=-55.85 WT2=-49.06 cross=none  MFI=55.3
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.72715 MFI=59.1 OK=False
# 16h: MACDh=44.90688 MFI=48.1 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:04:44.241816+00:00 [ETH] c=4477.49 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.3 | 6hOK=False 16hOK=False
# 2025-10-07T18:04:44.392364+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:05:45.722280+00:00 [BTC STATUS]
#   price=120970.51  next1hClose=54m 14s  ATR1h=808.27
#   1h: WT1=-75.08 WT2=-71.36 cross=none  MFI=44.4
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-588.28890 MFI=64.0 OK=False
# 16h: MACDh=701.56393 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:05:45.722404+00:00 [BTC] c=120970.51 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.4 | 6hOK=False 16hOK=True
# 2025-10-07T18:05:47.036503+00:00 [ETH STATUS]
#   price=4474.60  next1hClose=54m 12s  ATR1h=51.61
#   1h: WT1=-56.13 WT2=-49.15 cross=none  MFI=55.1
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.91159 MFI=59.1 OK=False
# 16h: MACDh=44.72245 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:05:47.036625+00:00 [ETH] c=4474.60 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.1 | 6hOK=False 16hOK=False
# 2025-10-07T18:05:47.160449+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:06:47.632640+00:00 [BTC STATUS]
#   price=120970.51  next1hClose=53m 12s  ATR1h=808.27
#   1h: WT1=-75.08 WT2=-71.36 cross=none  MFI=44.4
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-588.28890 MFI=64.0 OK=False
# 16h: MACDh=701.56393 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:06:47.632774+00:00 [BTC] c=120970.51 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.4 | 6hOK=False 16hOK=True
# 2025-10-07T18:06:48.236180+00:00 [ETH STATUS]
#   price=4474.60  next1hClose=53m 11s  ATR1h=51.61
#   1h: WT1=-56.13 WT2=-49.15 cross=none  MFI=55.1
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.91159 MFI=59.1 OK=False
# 16h: MACDh=44.72245 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:06:48.236605+00:00 [ETH] c=4474.60 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.1 | 6hOK=False 16hOK=False
# 2025-10-07T18:06:48.356864+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:07:48.862679+00:00 [BTC STATUS]
#   price=120970.51  next1hClose=52m 11s  ATR1h=808.27
#   1h: WT1=-75.08 WT2=-71.36 cross=none  MFI=44.4
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-588.28890 MFI=64.0 OK=False
# 16h: MACDh=701.56393 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:07:48.862797+00:00 [BTC] c=120970.51 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.4 | 6hOK=False 16hOK=True
# 2025-10-07T18:07:49.609133+00:00 [ETH STATUS]
#   price=4474.60  next1hClose=52m 10s  ATR1h=51.61
#   1h: WT1=-56.13 WT2=-49.15 cross=none  MFI=55.1
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.91159 MFI=59.1 OK=False
# 16h: MACDh=44.72245 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:07:49.609245+00:00 [ETH] c=4474.60 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.1 | 6hOK=False 16hOK=False
# 2025-10-07T18:07:49.735916+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:08:50.175285+00:00 [BTC STATUS]
#   price=120970.51  next1hClose=51m 9s  ATR1h=808.27
#   1h: WT1=-75.08 WT2=-71.36 cross=none  MFI=44.4
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-588.28890 MFI=64.0 OK=False
# 16h: MACDh=701.56393 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:08:50.175431+00:00 [BTC] c=120970.51 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.4 | 6hOK=False 16hOK=True
# 2025-10-07T18:08:50.854756+00:00 [ETH STATUS]
#   price=4474.60  next1hClose=51m 9s  ATR1h=51.61
#   1h: WT1=-56.13 WT2=-49.15 cross=none  MFI=55.1
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.91159 MFI=59.1 OK=False
# 16h: MACDh=44.72245 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:08:50.854861+00:00 [ETH] c=4474.60 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.1 | 6hOK=False 16hOK=False
# 2025-10-07T18:08:51.084445+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:09:51.587571+00:00 [BTC STATUS]
#   price=120970.51  next1hClose=50m 8s  ATR1h=808.27
#   1h: WT1=-75.08 WT2=-71.36 cross=none  MFI=44.4
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-588.28890 MFI=64.0 OK=False
# 16h: MACDh=701.56393 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:09:51.587687+00:00 [BTC] c=120970.51 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.4 | 6hOK=False 16hOK=True
# 2025-10-07T18:09:52.142851+00:00 [ETH STATUS]
#   price=4474.60  next1hClose=50m 7s  ATR1h=51.61
#   1h: WT1=-56.13 WT2=-49.15 cross=none  MFI=55.1
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.91159 MFI=59.1 OK=False
# 16h: MACDh=44.72245 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:09:52.142961+00:00 [ETH] c=4474.60 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.1 | 6hOK=False 16hOK=False
# 2025-10-07T18:09:52.301007+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:10:53.561597+00:00 [BTC STATUS]
#   price=121199.97  next1hClose=49m 6s  ATR1h=810.82
#   1h: WT1=-74.71 WT2=-71.24 cross=none  MFI=44.3
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.64529 MFI=64.0 OK=False
# 16h: MACDh=716.20754 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:10:53.561733+00:00 [BTC] c=121199.97 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.3 | 6hOK=False 16hOK=True
# 2025-10-07T18:10:54.865895+00:00 [ETH STATUS]
#   price=4478.07  next1hClose=49m 5s  ATR1h=51.83
#   1h: WT1=-55.95 WT2=-49.09 cross=none  MFI=54.8
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.69014 MFI=59.0 OK=False
# 16h: MACDh=44.94390 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:10:54.866009+00:00 [ETH] c=4478.07 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.8 | 6hOK=False 16hOK=False
# 2025-10-07T18:10:55.000312+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:11:55.600275+00:00 [BTC STATUS]
#   price=121199.97  next1hClose=48m 4s  ATR1h=810.82
#   1h: WT1=-74.71 WT2=-71.24 cross=none  MFI=44.3
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.64529 MFI=64.0 OK=False
# 16h: MACDh=716.20754 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:11:55.600398+00:00 [BTC] c=121199.97 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.3 | 6hOK=False 16hOK=True
# 2025-10-07T18:11:56.171015+00:00 [ETH STATUS]
#   price=4478.07  next1hClose=48m 3s  ATR1h=51.83
#   1h: WT1=-55.95 WT2=-49.09 cross=none  MFI=54.8
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.69014 MFI=59.0 OK=False
# 16h: MACDh=44.94390 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:11:56.171125+00:00 [ETH] c=4478.07 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.8 | 6hOK=False 16hOK=False
# 2025-10-07T18:11:56.308131+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:12:56.784474+00:00 [BTC STATUS]
#   price=121199.97  next1hClose=47m 3s  ATR1h=810.82
#   1h: WT1=-74.71 WT2=-71.24 cross=none  MFI=44.3
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.64529 MFI=64.0 OK=False
# 16h: MACDh=716.20754 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:12:56.784615+00:00 [BTC] c=121199.97 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.3 | 6hOK=False 16hOK=True
# 2025-10-07T18:12:57.427909+00:00 [ETH STATUS]
#   price=4478.07  next1hClose=47m 2s  ATR1h=51.83
#   1h: WT1=-55.95 WT2=-49.09 cross=none  MFI=54.8
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.69014 MFI=59.0 OK=False
# 16h: MACDh=44.94390 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:12:57.428013+00:00 [ETH] c=4478.07 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.8 | 6hOK=False 16hOK=False
# 2025-10-07T18:12:57.503963+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:13:58.015232+00:00 [BTC STATUS]
#   price=121199.97  next1hClose=46m 1s  ATR1h=810.82
#   1h: WT1=-74.71 WT2=-71.24 cross=none  MFI=44.3
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.64529 MFI=64.0 OK=False
# 16h: MACDh=716.20754 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:13:58.015357+00:00 [BTC] c=121199.97 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.3 | 6hOK=False 16hOK=True
# 2025-10-07T18:13:58.608013+00:00 [ETH STATUS]
#   price=4478.07  next1hClose=46m 1s  ATR1h=51.83
#   1h: WT1=-55.95 WT2=-49.09 cross=none  MFI=54.8
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.69014 MFI=59.0 OK=False
# 16h: MACDh=44.94390 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:13:58.608116+00:00 [ETH] c=4478.07 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.8 | 6hOK=False 16hOK=False
# 2025-10-07T18:13:58.747638+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:14:59.347977+00:00 [BTC STATUS]
#   price=121199.97  next1hClose=45m 0s  ATR1h=810.82
#   1h: WT1=-74.71 WT2=-71.24 cross=none  MFI=44.3
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.64529 MFI=64.0 OK=False
# 16h: MACDh=716.20754 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:14:59.348121+00:00 [BTC] c=121199.97 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.3 | 6hOK=False 16hOK=True
# 2025-10-07T18:14:59.984616+00:00 [ETH STATUS]
#   price=4478.07  next1hClose=45m 0s  ATR1h=51.83
#   1h: WT1=-55.95 WT2=-49.09 cross=none  MFI=54.8
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.69014 MFI=59.0 OK=False
# 16h: MACDh=44.94390 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:14:59.984737+00:00 [ETH] c=4478.07 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.8 | 6hOK=False 16hOK=False
# 2025-10-07T18:15:00.101685+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:16:01.375158+00:00 [BTC STATUS]
#   price=121210.01  next1hClose=43m 58s  ATR1h=821.81
#   1h: WT1=-74.41 WT2=-71.14 cross=none  MFI=44.2
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.00457 MFI=64.0 OK=False
# 16h: MACDh=716.84827 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:16:01.375281+00:00 [BTC] c=121210.01 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.2 | 6hOK=False 16hOK=True
# 2025-10-07T18:16:02.743968+00:00 [ETH STATUS]
#   price=4482.80  next1hClose=43m 57s  ATR1h=52.15
#   1h: WT1=-55.70 WT2=-49.01 cross=none  MFI=54.7
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.38828 MFI=59.0 OK=False
# 16h: MACDh=45.24575 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:16:02.744079+00:00 [ETH] c=4482.80 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.7 | 6hOK=False 16hOK=False
# 2025-10-07T18:16:02.908008+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:17:03.471890+00:00 [BTC STATUS]
#   price=121210.01  next1hClose=42m 56s  ATR1h=821.81
#   1h: WT1=-74.41 WT2=-71.14 cross=none  MFI=44.2
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.00457 MFI=64.0 OK=False
# 16h: MACDh=716.84827 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:17:03.472004+00:00 [BTC] c=121210.01 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.2 | 6hOK=False 16hOK=True
# 2025-10-07T18:17:04.098438+00:00 [ETH STATUS]
#   price=4482.80  next1hClose=42m 55s  ATR1h=52.15
#   1h: WT1=-55.70 WT2=-49.01 cross=none  MFI=54.7
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.38828 MFI=59.0 OK=False
# 16h: MACDh=45.24575 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:17:04.098561+00:00 [ETH] c=4482.80 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.7 | 6hOK=False 16hOK=False
# 2025-10-07T18:17:04.170709+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:18:04.709590+00:00 [BTC STATUS]
#   price=121210.01  next1hClose=41m 55s  ATR1h=821.81
#   1h: WT1=-74.41 WT2=-71.14 cross=none  MFI=44.2
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.00457 MFI=64.0 OK=False
# 16h: MACDh=716.84827 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:18:04.709715+00:00 [BTC] c=121210.01 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.2 | 6hOK=False 16hOK=True
# 2025-10-07T18:18:05.299753+00:00 [ETH STATUS]
#   price=4482.80  next1hClose=41m 54s  ATR1h=52.15
#   1h: WT1=-55.70 WT2=-49.01 cross=none  MFI=54.7
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.38828 MFI=59.0 OK=False
# 16h: MACDh=45.24575 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:18:05.299857+00:00 [ETH] c=4482.80 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.7 | 6hOK=False 16hOK=False
# 2025-10-07T18:18:05.425027+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:19:06.014175+00:00 [BTC STATUS]
#   price=121210.01  next1hClose=40m 53s  ATR1h=821.81
#   1h: WT1=-74.41 WT2=-71.14 cross=none  MFI=44.2
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.00457 MFI=64.0 OK=False
# 16h: MACDh=716.84827 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:19:06.014293+00:00 [BTC] c=121210.01 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.2 | 6hOK=False 16hOK=True
# 2025-10-07T18:19:06.586050+00:00 [ETH STATUS]
#   price=4482.80  next1hClose=40m 53s  ATR1h=52.15
#   1h: WT1=-55.70 WT2=-49.01 cross=none  MFI=54.7
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.38828 MFI=59.0 OK=False
# 16h: MACDh=45.24575 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:19:06.586161+00:00 [ETH] c=4482.80 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.7 | 6hOK=False 16hOK=False
# 2025-10-07T18:19:06.846593+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:20:07.383490+00:00 [BTC STATUS]
#   price=121210.01  next1hClose=39m 52s  ATR1h=821.81
#   1h: WT1=-74.41 WT2=-71.14 cross=none  MFI=44.2
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-573.00457 MFI=64.0 OK=False
# 16h: MACDh=716.84827 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:20:07.383622+00:00 [BTC] c=121210.01 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.2 | 6hOK=False 16hOK=True
# 2025-10-07T18:20:07.934973+00:00 [ETH STATUS]
#   price=4482.80  next1hClose=39m 52s  ATR1h=52.15
#   1h: WT1=-55.70 WT2=-49.01 cross=none  MFI=54.7
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-16.38828 MFI=59.0 OK=False
# 16h: MACDh=45.24575 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:20:07.935096+00:00 [ETH] c=4482.80 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.7 | 6hOK=False 16hOK=False
# 2025-10-07T18:20:08.040191+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:21:09.351708+00:00 [BTC STATUS]
#   price=121054.80  next1hClose=38m 50s  ATR1h=821.81
#   1h: WT1=-74.70 WT2=-71.24 cross=none  MFI=44.0
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-582.90971 MFI=63.9 OK=False
# 16h: MACDh=706.94313 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:21:09.351815+00:00 [BTC] c=121054.80 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.0 | 6hOK=False 16hOK=True
# 2025-10-07T18:21:10.531158+00:00 [ETH STATUS]
#   price=4470.27  next1hClose=38m 49s  ATR1h=52.54
#   1h: WT1=-56.19 WT2=-49.17 cross=none  MFI=54.4
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.28173 MFI=58.9 OK=False
# 16h: MACDh=44.44612 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:21:10.531264+00:00 [ETH] c=4470.27 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.4 | 6hOK=False 16hOK=False
# 2025-10-07T18:21:10.647960+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:22:11.194059+00:00 [BTC STATUS]
#   price=121054.80  next1hClose=37m 48s  ATR1h=821.81
#   1h: WT1=-74.70 WT2=-71.24 cross=none  MFI=44.0
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-582.90971 MFI=63.9 OK=False
# 16h: MACDh=706.94313 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:22:11.194204+00:00 [BTC] c=121054.80 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.0 | 6hOK=False 16hOK=True
# 2025-10-07T18:22:11.861187+00:00 [ETH STATUS]
#   price=4470.27  next1hClose=37m 48s  ATR1h=52.54
#   1h: WT1=-56.19 WT2=-49.17 cross=none  MFI=54.4
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.28173 MFI=58.9 OK=False
# 16h: MACDh=44.44612 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:22:11.861334+00:00 [ETH] c=4470.27 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.4 | 6hOK=False 16hOK=False
# 2025-10-07T18:22:11.930350+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:23:12.382245+00:00 [BTC STATUS]
#   price=121054.80  next1hClose=36m 47s  ATR1h=821.81
#   1h: WT1=-74.70 WT2=-71.24 cross=none  MFI=44.0
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-582.90971 MFI=63.9 OK=False
# 16h: MACDh=706.94313 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:23:12.382356+00:00 [BTC] c=121054.80 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.0 | 6hOK=False 16hOK=True
# 2025-10-07T18:23:13.065276+00:00 [ETH STATUS]
#   price=4470.27  next1hClose=36m 46s  ATR1h=52.54
#   1h: WT1=-56.19 WT2=-49.17 cross=none  MFI=54.4
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.28173 MFI=58.9 OK=False
# 16h: MACDh=44.44612 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:23:13.065389+00:00 [ETH] c=4470.27 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.4 | 6hOK=False 16hOK=False
# 2025-10-07T18:23:13.182178+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:24:13.771001+00:00 [BTC STATUS]
#   price=121054.80  next1hClose=35m 46s  ATR1h=821.81
#   1h: WT1=-74.70 WT2=-71.24 cross=none  MFI=44.0
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-582.90971 MFI=63.9 OK=False
# 16h: MACDh=706.94313 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:24:13.771128+00:00 [BTC] c=121054.80 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.0 | 6hOK=False 16hOK=True
# 2025-10-07T18:24:14.424115+00:00 [ETH STATUS]
#   price=4470.27  next1hClose=35m 45s  ATR1h=52.54
#   1h: WT1=-56.19 WT2=-49.17 cross=none  MFI=54.4
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.28173 MFI=58.9 OK=False
# 16h: MACDh=44.44612 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:24:14.424227+00:00 [ETH] c=4470.27 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.4 | 6hOK=False 16hOK=False
# 2025-10-07T18:24:14.547130+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:25:15.008867+00:00 [BTC STATUS]
#   price=121054.80  next1hClose=34m 44s  ATR1h=821.81
#   1h: WT1=-74.70 WT2=-71.24 cross=none  MFI=44.0
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-582.90971 MFI=63.9 OK=False
# 16h: MACDh=706.94313 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:25:15.008977+00:00 [BTC] c=121054.80 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=44.0 | 6hOK=False 16hOK=True
# 2025-10-07T18:25:15.643483+00:00 [ETH STATUS]
#   price=4470.27  next1hClose=34m 44s  ATR1h=52.54
#   1h: WT1=-56.19 WT2=-49.17 cross=none  MFI=54.4
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.28173 MFI=58.9 OK=False
# 16h: MACDh=44.44612 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:25:15.643605+00:00 [ETH] c=4470.27 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.4 | 6hOK=False 16hOK=False
# 2025-10-07T18:25:15.724071+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:26:17.157347+00:00 [BTC STATUS]
#   price=120800.00  next1hClose=33m 42s  ATR1h=833.16
#   1h: WT1=-75.44 WT2=-71.49 cross=none  MFI=43.8
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-599.17045 MFI=63.8 OK=False
# 16h: MACDh=690.68239 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:26:17.157485+00:00 [BTC] c=120800.00 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.8 | 6hOK=False 16hOK=True
# 2025-10-07T18:26:18.217981+00:00 [ETH STATUS]
#   price=4468.50  next1hClose=33m 41s  ATR1h=52.54
#   1h: WT1=-56.23 WT2=-49.19 cross=none  MFI=54.2
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.30087 MFI=58.9 OK=False
# 16h: MACDh=44.33316 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:26:18.218100+00:00 [ETH] c=4468.50 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.2 | 6hOK=False 16hOK=False
# 2025-10-07T18:26:18.279428+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:27:18.732462+00:00 [BTC STATUS]
#   price=120800.00  next1hClose=32m 41s  ATR1h=833.16
#   1h: WT1=-75.44 WT2=-71.49 cross=none  MFI=43.8
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-599.17045 MFI=63.8 OK=False
# 16h: MACDh=690.68239 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:27:18.732594+00:00 [BTC] c=120800.00 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.8 | 6hOK=False 16hOK=True
# 2025-10-07T18:27:19.274177+00:00 [ETH STATUS]
#   price=4468.50  next1hClose=32m 40s  ATR1h=52.54
#   1h: WT1=-56.23 WT2=-49.19 cross=none  MFI=54.2
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.30087 MFI=58.9 OK=False
# 16h: MACDh=44.33316 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:27:19.274292+00:00 [ETH] c=4468.50 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.2 | 6hOK=False 16hOK=False
# 2025-10-07T18:27:19.403967+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:28:19.924220+00:00 [BTC STATUS]
#   price=120800.00  next1hClose=31m 40s  ATR1h=833.16
#   1h: WT1=-75.44 WT2=-71.49 cross=none  MFI=43.8
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-599.17045 MFI=63.8 OK=False
# 16h: MACDh=690.68239 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:28:19.924343+00:00 [BTC] c=120800.00 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.8 | 6hOK=False 16hOK=True
# 2025-10-07T18:28:20.502899+00:00 [ETH STATUS]
#   price=4468.50  next1hClose=31m 39s  ATR1h=52.54
#   1h: WT1=-56.23 WT2=-49.19 cross=none  MFI=54.2
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.30087 MFI=58.9 OK=False
# 16h: MACDh=44.33316 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:28:20.503030+00:00 [ETH] c=4468.50 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.2 | 6hOK=False 16hOK=False
# 2025-10-07T18:28:20.590898+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:29:21.114119+00:00 [BTC STATUS]
#   price=120800.00  next1hClose=30m 38s  ATR1h=833.16
#   1h: WT1=-75.44 WT2=-71.49 cross=none  MFI=43.8
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-599.17045 MFI=63.8 OK=False
# 16h: MACDh=690.68239 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:29:21.114236+00:00 [BTC] c=120800.00 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.8 | 6hOK=False 16hOK=True
# 2025-10-07T18:29:21.774250+00:00 [ETH STATUS]
#   price=4468.50  next1hClose=30m 38s  ATR1h=52.54
#   1h: WT1=-56.23 WT2=-49.19 cross=none  MFI=54.2
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.30087 MFI=58.9 OK=False
# 16h: MACDh=44.33316 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:29:21.774362+00:00 [ETH] c=4468.50 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.2 | 6hOK=False 16hOK=False
# 2025-10-07T18:29:21.910648+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:30:22.502364+00:00 [BTC STATUS]
#   price=120800.00  next1hClose=29m 37s  ATR1h=833.16
#   1h: WT1=-75.44 WT2=-71.49 cross=none  MFI=43.8
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-599.17045 MFI=63.8 OK=False
# 16h: MACDh=690.68239 MFI=58.3 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:30:22.502490+00:00 [BTC] c=120800.00 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.8 | 6hOK=False 16hOK=True
# 2025-10-07T18:30:23.126166+00:00 [ETH STATUS]
#   price=4468.50  next1hClose=29m 36s  ATR1h=52.54
#   1h: WT1=-56.23 WT2=-49.19 cross=none  MFI=54.2
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.30087 MFI=58.9 OK=False
# 16h: MACDh=44.33316 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:30:23.126275+00:00 [ETH] c=4468.50 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.2 | 6hOK=False 16hOK=False
# 2025-10-07T18:30:23.262135+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:31:24.556791+00:00 [BTC STATUS]
#   price=120799.30  next1hClose=28m 35s  ATR1h=841.30
#   1h: WT1=-75.64 WT2=-71.55 cross=none  MFI=43.6
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-599.21512 MFI=63.8 OK=False
# 16h: MACDh=690.63771 MFI=58.2 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:31:24.556895+00:00 [BTC] c=120799.30 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.6 | 6hOK=False 16hOK=True
# 2025-10-07T18:31:25.801100+00:00 [ETH STATUS]
#   price=4466.19  next1hClose=28m 34s  ATR1h=52.81
#   1h: WT1=-56.39 WT2=-49.24 cross=none  MFI=54.0
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.44829 MFI=58.9 OK=False
# 16h: MACDh=44.18574 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:31:25.801216+00:00 [ETH] c=4466.19 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.0 | 6hOK=False 16hOK=False
# 2025-10-07T18:31:25.922007+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:32:26.467587+00:00 [BTC STATUS]
#   price=120799.30  next1hClose=27m 33s  ATR1h=841.30
#   1h: WT1=-75.64 WT2=-71.55 cross=none  MFI=43.6
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-599.21512 MFI=63.8 OK=False
# 16h: MACDh=690.63771 MFI=58.2 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:32:26.467697+00:00 [BTC] c=120799.30 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.6 | 6hOK=False 16hOK=True
# 2025-10-07T18:32:27.058301+00:00 [ETH STATUS]
#   price=4466.19  next1hClose=27m 32s  ATR1h=52.81
#   1h: WT1=-56.39 WT2=-49.24 cross=none  MFI=54.0
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.44829 MFI=58.9 OK=False
# 16h: MACDh=44.18574 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:32:27.058422+00:00 [ETH] c=4466.19 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.0 | 6hOK=False 16hOK=False
# 2025-10-07T18:32:27.127725+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:33:27.716100+00:00 [BTC STATUS]
#   price=120799.30  next1hClose=26m 32s  ATR1h=841.30
#   1h: WT1=-75.64 WT2=-71.55 cross=none  MFI=43.6
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-599.21512 MFI=63.8 OK=False
# 16h: MACDh=690.63771 MFI=58.2 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:33:27.716206+00:00 [BTC] c=120799.30 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.6 | 6hOK=False 16hOK=True
# 2025-10-07T18:33:28.297359+00:00 [ETH STATUS]
#   price=4466.19  next1hClose=26m 31s  ATR1h=52.81
#   1h: WT1=-56.39 WT2=-49.24 cross=none  MFI=54.0
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.44829 MFI=58.9 OK=False
# 16h: MACDh=44.18574 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:33:28.297463+00:00 [ETH] c=4466.19 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.0 | 6hOK=False 16hOK=False
# 2025-10-07T18:33:28.439883+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:34:28.884377+00:00 [BTC STATUS]
#   price=120799.30  next1hClose=25m 31s  ATR1h=841.30
#   1h: WT1=-75.64 WT2=-71.55 cross=none  MFI=43.6
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-599.21512 MFI=63.8 OK=False
# 16h: MACDh=690.63771 MFI=58.2 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:34:28.884492+00:00 [BTC] c=120799.30 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.6 | 6hOK=False 16hOK=True
# 2025-10-07T18:34:29.443266+00:00 [ETH STATUS]
#   price=4466.19  next1hClose=25m 30s  ATR1h=52.81
#   1h: WT1=-56.39 WT2=-49.24 cross=none  MFI=54.0
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.44829 MFI=58.9 OK=False
# 16h: MACDh=44.18574 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:34:29.443371+00:00 [ETH] c=4466.19 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.0 | 6hOK=False 16hOK=False
# 2025-10-07T18:34:29.539528+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:35:30.018571+00:00 [BTC STATUS]
#   price=120799.30  next1hClose=24m 29s  ATR1h=841.30
#   1h: WT1=-75.64 WT2=-71.55 cross=none  MFI=43.6
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-599.21512 MFI=63.8 OK=False
# 16h: MACDh=690.63771 MFI=58.2 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:35:30.018682+00:00 [BTC] c=120799.30 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.6 | 6hOK=False 16hOK=True
# 2025-10-07T18:35:30.648655+00:00 [ETH STATUS]
#   price=4466.19  next1hClose=24m 29s  ATR1h=52.81
#   1h: WT1=-56.39 WT2=-49.24 cross=none  MFI=54.0
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.44829 MFI=58.9 OK=False
# 16h: MACDh=44.18574 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:35:30.648758+00:00 [ETH] c=4466.19 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=54.0 | 6hOK=False 16hOK=False
# 2025-10-07T18:35:30.777339+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:36:32.012972+00:00 [BTC STATUS]
#   price=120774.08  next1hClose=23m 27s  ATR1h=841.30
#   1h: WT1=-75.69 WT2=-71.57 cross=none  MFI=43.5
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-600.82460 MFI=63.7 OK=False
# 16h: MACDh=689.02823 MFI=58.2 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:36:32.013110+00:00 [BTC] c=120774.08 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.5 | 6hOK=False 16hOK=True
# 2025-10-07T18:36:33.241692+00:00 [ETH STATUS]
#   price=4462.24  next1hClose=23m 26s  ATR1h=52.81
#   1h: WT1=-56.49 WT2=-49.27 cross=none  MFI=53.9
#       lastCrossBarsAgo: up=8, dn=4
#   6h: MACDh=-17.70037 MFI=58.8 OK=False
# 16h: MACDh=43.93366 MFI=48.0 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T18:36:33.241817+00:00 [ETH] c=4462.24 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=53.9 | 6hOK=False 16hOK=False
# 2025-10-07T18:36:33.307895+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T18:37:33.807009+00:00 [BTC STATUS]
#   price=120774.08  next1hClose=22m 26s  ATR1h=841.30
#   1h: WT1=-75.69 WT2=-71.57 cross=none  MFI=43.5
#       lastCrossBarsAgo: up=9, dn=4
#   6h: MACDh=-600.82460 MFI=63.7 OK=False
# 16h: MACDh=689.02823 MFI=58.2 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T18:37:33.807126+00:00 [BTC] c=120774.08 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=43.5 | 6hOK=False 16hOK=True
# 2025-10-07T18:37:34.448133+00:00 [ETH STATUS]
#   price=4462.24  next1hClose=22m 25s  ATR1h=52.81
#   1h: WT1=-56.49 WT2=-49.27 cross=none  MFI=53.9
#       lastCrossBarsAgo: up=8, dn=4
# ...
#   price=121903.44  next1hClose=49m 8s  ATR1h=862.68
#   1h: WT1=-50.94 WT2=-56.82 cross=none  MFI=48.3
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-522.67859 MFI=62.9 OK=False
# 16h: MACDh=761.10135 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:10:51.729840+00:00 [BTC] c=121903.44 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.3 | 6hOK=False 16hOK=True
# 2025-10-07T22:10:52.874837+00:00 [ETH STATUS]
#   price=4490.00  next1hClose=49m 7s  ATR1h=52.30
#   1h: WT1=-50.31 WT2=-52.38 cross=none  MFI=55.7
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.65502 MFI=57.8 OK=False
# 16h: MACDh=45.70524 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:10:52.874947+00:00 [ETH] c=4490.00 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.7 | 6hOK=False 16hOK=False
# 2025-10-07T22:10:52.989429+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:11:53.531170+00:00 [BTC STATUS]
#   price=121903.44  next1hClose=48m 6s  ATR1h=862.68
#   1h: WT1=-50.94 WT2=-56.82 cross=none  MFI=48.3
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-526.59891 MFI=62.9 OK=False
# 16h: MACDh=761.10135 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:11:53.531277+00:00 [BTC] c=121903.44 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.3 | 6hOK=False 16hOK=True
# 2025-10-07T22:11:54.167894+00:00 [ETH STATUS]
#   price=4490.00  next1hClose=48m 5s  ATR1h=52.30
#   1h: WT1=-50.31 WT2=-52.38 cross=none  MFI=55.7
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.90391 MFI=57.8 OK=False
# 16h: MACDh=45.70524 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:11:54.168000+00:00 [ETH] c=4490.00 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.7 | 6hOK=False 16hOK=False
# 2025-10-07T22:11:54.280847+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:12:54.695700+00:00 [BTC STATUS]
#   price=121903.44  next1hClose=47m 5s  ATR1h=862.68
#   1h: WT1=-50.94 WT2=-56.82 cross=none  MFI=48.3
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-526.59891 MFI=62.9 OK=False
# 16h: MACDh=761.10135 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:12:54.695815+00:00 [BTC] c=121903.44 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.3 | 6hOK=False 16hOK=True
# 2025-10-07T22:12:55.147454+00:00 [ETH STATUS]
#   price=4490.00  next1hClose=47m 4s  ATR1h=52.30
#   1h: WT1=-50.31 WT2=-52.38 cross=none  MFI=55.7
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.90391 MFI=57.8 OK=False
# 16h: MACDh=45.70524 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:12:55.147575+00:00 [ETH] c=4490.00 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.7 | 6hOK=False 16hOK=False
# 2025-10-07T22:12:55.335853+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:13:55.780415+00:00 [BTC STATUS]
#   price=121903.44  next1hClose=46m 4s  ATR1h=862.68
#   1h: WT1=-50.94 WT2=-56.82 cross=none  MFI=48.3
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-526.59891 MFI=62.9 OK=False
# 16h: MACDh=761.10135 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:13:55.780524+00:00 [BTC] c=121903.44 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.3 | 6hOK=False 16hOK=True
# 2025-10-07T22:13:56.290777+00:00 [ETH STATUS]
#   price=4490.00  next1hClose=46m 3s  ATR1h=52.30
#   1h: WT1=-50.31 WT2=-52.38 cross=none  MFI=55.7
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.90391 MFI=57.8 OK=False
# 16h: MACDh=45.70524 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:13:56.290876+00:00 [ETH] c=4490.00 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.7 | 6hOK=False 16hOK=False
# 2025-10-07T22:13:56.353681+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:14:56.742880+00:00 [BTC STATUS]
#   price=121903.44  next1hClose=45m 3s  ATR1h=862.68
#   1h: WT1=-50.94 WT2=-56.82 cross=none  MFI=48.3
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-526.59891 MFI=62.9 OK=False
# 16h: MACDh=761.10135 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:14:56.742985+00:00 [BTC] c=121903.44 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.3 | 6hOK=False 16hOK=True
# 2025-10-07T22:14:57.439010+00:00 [ETH STATUS]
#   price=4490.00  next1hClose=45m 2s  ATR1h=52.30
#   1h: WT1=-50.31 WT2=-52.38 cross=none  MFI=55.7
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.90391 MFI=57.8 OK=False
# 16h: MACDh=45.70524 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:14:57.439127+00:00 [ETH] c=4490.00 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.7 | 6hOK=False 16hOK=False
# 2025-10-07T22:14:57.582998+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:15:58.765720+00:00 [BTC STATUS]
#   price=122102.76  next1hClose=44m 1s  ATR1h=863.89
#   1h: WT1=-50.07 WT2=-56.53 cross=none  MFI=48.3
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-526.59891 MFI=62.9 OK=False
# 16h: MACDh=773.82148 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:15:58.765833+00:00 [BTC] c=122102.76 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.3 | 6hOK=False 16hOK=True
# 2025-10-07T22:15:59.808334+00:00 [ETH STATUS]
#   price=4500.01  next1hClose=44m 0s  ATR1h=52.50
#   1h: WT1=-49.76 WT2=-52.20 cross=none  MFI=55.6
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.90391 MFI=57.8 OK=False
# 16h: MACDh=46.34406 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:15:59.808456+00:00 [ETH] c=4500.01 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.6 | 6hOK=False 16hOK=False
# 2025-10-07T22:15:59.924630+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:17:00.446372+00:00 [BTC STATUS]
#   price=122102.76  next1hClose=42m 59s  ATR1h=863.89
#   1h: WT1=-50.07 WT2=-56.53 cross=none  MFI=48.3
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-516.17366 MFI=62.9 OK=False
# 16h: MACDh=773.82148 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:17:00.446487+00:00 [BTC] c=122102.76 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.3 | 6hOK=False 16hOK=True
# 2025-10-07T22:17:01.095985+00:00 [ETH STATUS]
#   price=4500.01  next1hClose=42m 58s  ATR1h=52.50
#   1h: WT1=-49.76 WT2=-52.20 cross=none  MFI=55.6
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.26445 MFI=57.8 OK=False
# 16h: MACDh=46.34406 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:17:01.096094+00:00 [ETH] c=4500.01 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.6 | 6hOK=False 16hOK=False
# 2025-10-07T22:17:01.206444+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:18:01.637858+00:00 [BTC STATUS]
#   price=122102.76  next1hClose=41m 58s  ATR1h=863.89
#   1h: WT1=-50.07 WT2=-56.53 cross=none  MFI=48.3
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-516.17366 MFI=62.9 OK=False
# 16h: MACDh=773.82148 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:18:01.637972+00:00 [BTC] c=122102.76 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.3 | 6hOK=False 16hOK=True
# 2025-10-07T22:18:02.183570+00:00 [ETH STATUS]
#   price=4500.01  next1hClose=41m 57s  ATR1h=52.50
#   1h: WT1=-49.76 WT2=-52.20 cross=none  MFI=55.6
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.26445 MFI=57.8 OK=False
# 16h: MACDh=46.34406 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:18:02.183677+00:00 [ETH] c=4500.01 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.6 | 6hOK=False 16hOK=False
# 2025-10-07T22:18:02.324857+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:19:02.839586+00:00 [BTC STATUS]
#   price=122102.76  next1hClose=40m 57s  ATR1h=863.89
#   1h: WT1=-50.07 WT2=-56.53 cross=none  MFI=48.3
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-516.17366 MFI=62.9 OK=False
# 16h: MACDh=773.82148 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:19:02.839700+00:00 [BTC] c=122102.76 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.3 | 6hOK=False 16hOK=True
# 2025-10-07T22:19:03.516212+00:00 [ETH STATUS]
#   price=4500.01  next1hClose=40m 56s  ATR1h=52.50
#   1h: WT1=-49.76 WT2=-52.20 cross=none  MFI=55.6
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.26445 MFI=57.8 OK=False
# 16h: MACDh=46.34406 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:19:03.516326+00:00 [ETH] c=4500.01 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.6 | 6hOK=False 16hOK=False
# 2025-10-07T22:19:03.583897+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:20:04.055223+00:00 [BTC STATUS]
#   price=122102.76  next1hClose=39m 55s  ATR1h=863.89
#   1h: WT1=-50.07 WT2=-56.53 cross=none  MFI=48.3
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-516.17366 MFI=62.9 OK=False
# 16h: MACDh=773.82148 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:20:04.055336+00:00 [BTC] c=122102.76 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.3 | 6hOK=False 16hOK=True
# 2025-10-07T22:20:04.666058+00:00 [ETH STATUS]
#   price=4500.01  next1hClose=39m 55s  ATR1h=52.50
#   1h: WT1=-49.76 WT2=-52.20 cross=none  MFI=55.6
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.26445 MFI=57.8 OK=False
# 16h: MACDh=46.34406 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:20:04.666169+00:00 [ETH] c=4500.01 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.6 | 6hOK=False 16hOK=False
# 2025-10-07T22:20:04.782157+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:21:06.137585+00:00 [BTC STATUS]
#   price=122105.77  next1hClose=38m 53s  ATR1h=872.81
#   1h: WT1=-49.53 WT2=-56.35 cross=none  MFI=48.2
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-516.17366 MFI=62.9 OK=False
# 16h: MACDh=774.01358 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:21:06.137696+00:00 [BTC] c=122105.77 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.2 | 6hOK=False 16hOK=True
# 2025-10-07T22:21:07.274074+00:00 [ETH STATUS]
#   price=4503.59  next1hClose=38m 52s  ATR1h=53.01
#   1h: WT1=-49.29 WT2=-52.04 cross=none  MFI=55.9
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.26445 MFI=57.8 OK=False
# 16h: MACDh=46.57252 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:21:07.274200+00:00 [ETH] c=4503.59 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.9 | 6hOK=False 16hOK=False
# 2025-10-07T22:21:07.539039+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:22:08.110867+00:00 [BTC STATUS]
#   price=122105.77  next1hClose=37m 51s  ATR1h=872.81
#   1h: WT1=-49.53 WT2=-56.35 cross=none  MFI=48.2
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-512.76133 MFI=62.9 OK=False
# 16h: MACDh=774.01358 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:22:08.110985+00:00 [BTC] c=122105.77 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.2 | 6hOK=False 16hOK=True
# 2025-10-07T22:22:08.715914+00:00 [ETH STATUS]
#   price=4503.59  next1hClose=37m 51s  ATR1h=53.01
#   1h: WT1=-49.29 WT2=-52.04 cross=none  MFI=55.9
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.04364 MFI=57.8 OK=False
# 16h: MACDh=46.57252 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:22:08.716017+00:00 [ETH] c=4503.59 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.9 | 6hOK=False 16hOK=False
# 2025-10-07T22:22:08.830716+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:23:09.252670+00:00 [BTC STATUS]
#   price=122105.77  next1hClose=36m 50s  ATR1h=872.81
#   1h: WT1=-49.53 WT2=-56.35 cross=none  MFI=48.2
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-512.76133 MFI=62.9 OK=False
# 16h: MACDh=774.01358 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:23:09.252778+00:00 [BTC] c=122105.77 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.2 | 6hOK=False 16hOK=True
# 2025-10-07T22:23:09.764661+00:00 [ETH STATUS]
#   price=4503.59  next1hClose=36m 50s  ATR1h=53.01
#   1h: WT1=-49.29 WT2=-52.04 cross=none  MFI=55.9
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.04364 MFI=57.8 OK=False
# 16h: MACDh=46.57252 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:23:09.764764+00:00 [ETH] c=4503.59 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.9 | 6hOK=False 16hOK=False
# 2025-10-07T22:23:09.832363+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
# 2025-10-07T22:24:10.251899+00:00 [BTC STATUS]
#   price=122105.77  next1hClose=35m 49s  ATR1h=872.81
#   1h: WT1=-49.53 WT2=-56.35 cross=none  MFI=48.2
#       lastCrossBarsAgo: up=3, dn=8
#   6h: MACDh=-512.76133 MFI=62.9 OK=False
# 16h: MACDh=774.01358 MFI=57.9 OK=True
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', 'MFI1h<=50', '6h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', '16h_regime_true']
# 2025-10-07T22:24:10.252009+00:00 [BTC] c=122105.77 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=48.2 | 6hOK=False 16hOK=True
# 2025-10-07T22:24:10.742232+00:00 [ETH STATUS]
#   price=4503.59  next1hClose=35m 49s  ATR1h=53.01
#   1h: WT1=-49.29 WT2=-52.04 cross=none  MFI=55.9
#       lastCrossBarsAgo: up=2, dn=8
#   6h: MACDh=-15.04364 MFI=57.8 OK=False
# 16h: MACDh=46.57252 MFI=47.6 OK=False
#   alignLong=1/4 blockedLong=['no_fresh_WT_up', '6h_regime_false', '16h_regime_false']
#   alignShort=2/4 blockedShort=['no_fresh_WT_dn', 'MFI1h>=50']
# 2025-10-07T22:24:10.742341+00:00 [ETH] c=4503.59 | L:1/4 S:2/4 | 1h:WT_up=False WT_dn=False MFI=55.9 | 6hOK=False 16hOK=False
# 2025-10-07T22:24:10.861266+00:00 [HEARTBEAT] equity=10000.00 open_positions=0
